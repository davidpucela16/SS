# %%
import RHS_for_v as RH
import numpy as np
from scipy import sparse
import matplotlib.pyplot as plt 
import matplotlib.patches as mpatches
import matplotlib.gridspec as gridspec
import scipy as sp
import scipy.sparse.linalg
import time

# %% [markdown]
# Implementation of the solution splitting technique with cylindrical symmetry around the vessel:
#
# $$-D \Delta \phi = - \delta_\Lambda q$$
#
# $$\phi \mathbf(x)=0 \quad on \quad \partial \Omega_{ext}$$
# $$\nabla_n \phi\mathbf(x)=0 \quad on \quad \partial \Omega_{east, west}$$
#
# $$\iiint_\Omega \delta_\Lambda f\mathbf(x) dV = \int_\Lambda f(s)ds$$
#
# $$\phi= \phi_s + \phi_r$$
#
# $\phi$ represents the scalar field that we want to recover
#
# $$\phi_s=G(r)q(s)$$
#
# with: $G(r)=-\frac{1}{2 \pi D}log(\frac{r}{R_v})$

# %% [markdown]
# $$\Delta \phi = \Delta (G(r)q(s)) + \Delta \phi_r$$
# $$-\delta_\Lambda \frac{q}{D} = (\Delta G(r))q(s) + 2\nabla G \cdot \nabla q + Gq"(s) +  \Delta \phi_r$$

# %% [markdown]
# For this particular problem we have:
# $$\Delta \phi_r = -G(r)\frac{d^2 q}{d s^2}$$
#
# with the following boundary conditions:

# %%
from importlib import reload
reload(RH)
plt.figure()
plt.plot(RH.k.z,RH.q_vessel)
plt.title("Source given by vessel")
plt.xlabel("s")
# Out:
# /home/pdavid/anaconda3/lib/python3.8/site-packages/scipy/sparse/_index.py:116: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# Text(0.5, 0, 's')

# %%
RH.compare_full_solutions(RH.rhs,  RH.r_rhs,"rhs", "real_rhs",[-1,0.8], "Contour RHSs")
rhs_forlater=RH.rhs

# %%
RH.plot_profile(5, RH.k.z, RH.k.r, RH.rhs, RH.r_rhs, "RHS real vs v")

# %%
RH.s_plot_profile(0, RH.k.z, RH.k.r, RH.rhs, RH.r_rhs,"RHS real vs v")

# %%
RH.plot_profile(-1, RH.k.z, RH.k.r, RH.rhs, RH.r_rhs,"RHS real vs v")

# %% [markdown]
# In the following code, the vessel containing cells and the west boundaries are modified to equal the "retro_engineered" right hand side. After this two operations are done we continue

# %%
#RH.rhs[:,-1]=RH.r_rhs[:,-1]
RH.rhs[0,:]=RH.r_rhs[0,:]
RHS=np.ndarray.flatten(RH.rhs)

# %%
sol=sp.sparse.linalg.spsolve(RH.Lap_operator, RHS).reshape(len(RH.k.r), len(RH.k.z))
sol_plus=sol+RH.sol_sing
RH.plott(sol_plus, "modified solution")
# Out:
# /home/pdavid/anaconda3/lib/python3.8/site-packages/scipy/sparse/linalg/dsolve/linsolve.py:144: SparseEfficiencyWarning: spsolve requires A be CSC or CSR matrix format
#   warn('spsolve requires A be CSC or CSR matrix format',

# %%
RH.compare_full_solutions(sol_plus,  RH.sol_real,"split_modified", "real_sol",[0,1], "Contour modified")

# %%
RH.compare_full_solutions(RH.rhs,  RH.r_rhs,"rhs", "real_rhs",[-1,0.8], "Contour RHSs")

# %%
RH.r_rhs[-1,:]
# Out:
# array([0.47478362, 0.47448086, 0.47357296, 0.47206107, 0.46994713,
#        0.46723383, 0.46392463, 0.46002375, 0.45553617, 0.45046761,
#        0.44482454, 0.43861415, 0.43184436, 0.42452381, 0.41666183,
#        0.40826845, 0.39935438, 0.38993098, 0.38001027, 0.3696049 ,
#        0.35872815, 0.34739389, 0.33561657, 0.32341122, 0.31079339,
#        0.29777919, 0.2843852 , 0.27062852, 0.25652669, 0.24209768,
#        0.22735992, 0.21233218, 0.19703364, 0.18148381, 0.16570252,
#        0.14970989, 0.13352633, 0.11717248, 0.10066918, 0.0840375 ])

# %%
first_der=RH.get_first_der(RH.q_vessel,RH.k.inc_z).dot(RH.q_vessel)
plt.plot(RH.k.z, first_der, label="first derivative vessel")
plt.legend()

# %%
plt.figure()
plt.plot(RH.k.r, RH.Green(RH.k.r, RH.k.Rv), label="Green function")
plt.plot(RH.k.r, -RH.Green(RH.k.r, RH.k.Rv)*first_der[-1], label="boundary value")
plt.legend()
plt.xlabel("r")
# Out:
# Text(0.5, 0, 'r')

# %%
f=plt.figure(figsize=(10,20))

# Create two subplots and unpack the output array immediately
f, (ax1, ax2, ax3) = plt.subplots(1, 3,figsize=(12,8) )
ax1.plot(RH.k.r[1:-1], RH.rhs[1:-1,-1])
ax1.set_title("computed boundary value RHS")
ax2.plot(RH.k.r[1:-1], RH.r_rhs[1:-1,-1])
ax2.set_title("real boundary value RHS")
ax3.plot(RH.k.r[1:-1], RH.r_rhs[1:-1,-1]/RH.rhs[1:-1,-1])
ax3.set_title("ratio")
# Out:
# Text(0.5, 1.0, 'ratio')

# %%
1/RH.hr
# Out:
# 40.0

# %% [markdown]
# Fully modified:

# %%
RH.rhs[:,-1]=RH.r_rhs[:,-1]
RH.rhs[0,:]=RH.r_rhs[0,:]
RHS=np.ndarray.flatten(RH.rhs)
sol=sp.sparse.linalg.spsolve(RH.Lap_operator, RHS).reshape(len(RH.k.r), len(RH.k.z))
sol_plus=sol+RH.sol_sing
RH.plott(sol_plus, "modified solution")
RH.compare_full_solutions(sol_plus,  RH.sol_real,"split_modified", "real_sol",[0,1], "Contour modified")
# Out:
# /home/pdavid/anaconda3/lib/python3.8/site-packages/scipy/sparse/linalg/dsolve/linsolve.py:144: SparseEfficiencyWarning: spsolve requires A be CSC or CSR matrix format
#   warn('spsolve requires A be CSC or CSR matrix format',

# %%
RH.rhs=rhs_forlater

# %%
RHS=np.ndarray.flatten(RH.rhs)
sol=sp.sparse.linalg.spsolve(RH.Lap_operator, RHS).reshape(len(RH.k.r), len(RH.k.z))
sol_plus=sol+RH.sol_sing
RH.plott(sol_plus, "modified solution")
RH.compare_full_solutions(sol_plus,  RH.sol_real,"split_modified", "real_sol",[0,1], "Contour modified")
